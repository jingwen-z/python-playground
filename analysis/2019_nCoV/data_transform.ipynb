# %%
import pandas as pd
from datetime import datetime, date
import numpy as np
from dateutil.relativedelta import relativedelta

# %%
now = datetime.now()
yesterday = (now + relativedelta(days=-1)).date()
# yesterday = date(2020, 5, 9)

filename = '%02d-%02d-%d.csv' % (yesterday.month, yesterday.day, yesterday.year)
df = pd.read_csv(filename)

# %%
df.head()

# %%
new_old_country_name = {
    'China':'Mainland China',
    'Hong Kong SAR':'Hong Kong',
    'Macao SAR':'Macau',
    'Taipei and environs':'Taiwan',
    'Taiwan*':'Taiwan',
    'Iran (Islamic Republic of)':'Iran',
    'Republic of Korea':'South Korea',
    'Korea, South':'South Korea',
    'Viet Nam':'Vietnam',
    'occupied Palestinian territory':'Palestine',
    'Russian Federation':'Russia',
    'Republic of Moldova':'Moldova',
    'Saint Martin':'St. Martin',
    'United Kingdom':'UK',
    'Czechia':'Czech Republic',
    'Congo (Kinshasa)':'Democratic Republic of the Congo',
    'Congo (Brazzaville)':'Republic of the Congo',
    'Republic of Ireland':'Ireland',
    'Guam':'US',
    'Puerto Rico':'US',
    'Gambia, The':'The Gambia',
    'Gambia':'The Gambia',
    'Bahamas, The':'The Bahamas',
    'Bahamas':'The Bahamas',
    'East Timor':'Timor-Leste',
    'Diamond Princess':'Diamond Princess cruise ship'
}

def unify_country_name(transfer_dict, country_name):
    if country_name in new_old_country_name:
        return new_old_country_name[country_name]
    else:
        return country_name

# %%
df = df[['Country_Region', 'Province_State', 'Confirmed', 'Recovered', 'Deaths', 'Last_Update']]
df.columns = ['countryName', 'cityName', 'confirmedCount', 'curedCount', 'deadCount', 'updateTime']

df['countryName'] = df['countryName'].apply(lambda x: unify_country_name(new_old_country_name, x))
df['updateTime'] = df['updateTime'].apply(lambda d: datetime.strptime(d, '%Y-%m-%d %H:%M:%S'))
df['Date_ymd'] = df['updateTime'].apply(lambda d: d.date())
df['Time_hms'] = df['updateTime'].apply(lambda d: d.time())

# df = df[(df['Date_ymd'] == yesterday) & \
#         ((df['confirmedCount'] > 0) | (df['curedCount'] > 0) | (df['deadCount'] > 0)) & \
#         (df['countryName'].isin(['Mainland China', 'Hong Kong', 'Taiwan', 'Macau',
#                                  'Reunion', 'Mayotte', 'Martinique', 'Guadeloupe',
#                                  'French Guiana', 'French Polynesia', 'St Martin',
#                                  'New Caledonia', 'Saint Barthelemy',
#                                  'Saint Pierre and Miquelon', 'Faroe Islands', 'Greenland'])==False)]

df = df[(df['Date_ymd'] >= yesterday) & \
        ((df['confirmedCount'] > 0) | (df['curedCount'] > 0) | (df['deadCount'] > 0)) & \
        (df['countryName'].isin(['Mainland China', 'Hong Kong', 'Taiwan', 'Macau', 'US'])==False) & \
        (df['cityName'].isin(['Reunion', 'Mayotte', 'Martinique', 'Guadeloupe', 'French Guiana',
                              'French Polynesia', 'St Martin', 'New Caledonia', 'Saint Barthelemy',
                              'Saint Pierre and Miquelon', 'Faroe Islands', 'Greenland'])==False)]


# df = df[(df['countryName'].isin(['Mainland China', 'Hong Kong', 'Taiwan', 'Macau'])==False)]

df['cityName'] = df['cityName'].fillna(df['countryName'])
df = df.drop(columns=['Date_ymd', 'Time_hms'])
df = df.sort_values('confirmedCount', ascending=False)

# %%
# df['updateTime'] = df['updateTime'].apply(lambda d: d + relativedelta(days=2))

# %%
df.head()

# %%
df[df['countryName']=='France']

# %%
country_continent_dict = {
    'Iran':'Asia',
    'Iraq':'Asia',
    'Oman':'Asia',
    'Laos':'Asia',
    'India':'Asia',
    'Japan':'Asia',
    'Qatar':'Asia',
    'Syria':'Asia',
    'Nepal':'Asia',
    'Burma':'Asia',
    'Yemen':'Asia',
    'Brunei':'Asia',
    'Bhutan':'Asia',
    'Israel':'Asia',
    'Jordan':'Asia',
    'Others':'Asia',
    'Kuwait':'Asia',
    'Vietnam':'Asia',
    'Georgia':'Asia',
    'Armenia':'Asia',
    'Bahrain':'Asia', 
    'Lebanon':'Asia',
    'Malaysia':'Asia',
    'Thailand':'Asia',
    'Pakistan':'Asia',
    'Maldives':'Asia',
    'Cambodia':'Asia',
    'Mongolia':'Asia',
    'Indonesia':'Asia',
    'Singapore':'Asia',
    'Sri Lanka':'Asia',
    'Palestine':'Asia',
    'Uzbekistan':'Asia',
    'Kazakhstan':'Asia',
    'Bangladesh':'Asia',
    'Azerbaijan':'Asia',
    'Kyrgyzstan':'Asia',
    'Cruise Ship':'Asia',
    'South Korea':'Asia',
    'Philippines':'Asia',
#     'East Timor':'Asia',
    'Afghanistan':'Asia',
    'Timor-Leste':'Asia',
    'Saudi Arabia':'Asia',
    'United Arab Emirates':'Asia',
    'Diamond Princess cruise ship':'Asia',
    'West Bank and Gaza':'Asia',
    'Tajikistan':'Asia',
#     '':'Asia',
#     '':'Asia',
    'UK':'Europe',
    'Malta':'Europe',
    'Aruba':'Europe',
    'Italy':'Europe',
    'Spain':'Europe',
    'Greece':'Europe',
    'France':'Europe',
    'Jersey':'Europe',
    'Norway':'Europe',
    'Sweden':'Europe',
    'Latvia':'Europe',
    'Kosovo':'Europe',
    'Turkey':'Europe',
    'Monaco':'Europe',
    'Cyprus':'Europe',
    'Poland':'Europe',
    'Serbia':'Europe',
    'Russia':'Europe',
    'Andorra':'Europe',
    'Ukraine':'Europe',
    'Austria':'Europe',
    'Iceland':'Europe',
    'Belgium':'Europe',
    'Denmark':'Europe',
    'Germany':'Europe',
    'Ireland':'Europe',
    'Hungary':'Europe',
    'Finland':'Europe',
    'Moldova':'Europe',
    'Belarus':'Europe',
    'Albania':'Europe',
    'Croatia':'Europe',
    'Estonia':'Europe',
    'Romania':'Europe',
    'Reunion':'Europe',
    'Mayotte':'Europe',
    'Slovenia':'Europe',
    'Bulgaria':'Europe',
    'Portugal':'Europe',
    'Slovakia':'Europe',
    'Holy See':'Europe',
    'Guernsey':'Europe',
    'Greenland':'Europe',
    'Lithuania':'Europe',
    'Gibraltar':'Europe',
    'Martinique':'Europe',
    'Luxembourg':'Europe',
    'San Marino':'Europe',
    'Montenegro':'Europe',
    'Guadeloupe':'Europe',
    'Switzerland':'Europe',
    'Netherlands':'Europe',
    'Vatican City':'Europe',
    'French Guiana':'Europe',
    'Faroe Islands':'Europe',
    'Liechtenstein':'Europe',
    'Cayman Islands':'Europe',
    'Czech Republic':'Europe',
    'Channel Islands':'Europe',
    'North Macedonia':'Europe',
    'Saint Barthelemy':'Europe',
    'Antigua and Barbuda':'Europe',
    'Republic of Ireland':'Europe',
    'Bosnia and Herzegovina':'Europe',
#     '':'Europe',
#     '':'Europe',
#     '':'Europe',
    'US':'North America',
    'Cuba':'North America',
    'Haiti':'North America',
    'Panama':'North America',
    'Canada':'North America',
    'Belize':'North America',
    'Mexico':'North America',
    'Jamaica':'North America',
    'Grenada':'North America',
    'Dominica':'North America',
    'Barbados':'North America',
    'Honduras':'North America',
    'Guatemala':'North America',
    'Nicaragua':'North America',
    'Costa Rica':'North America',
    'St. Martin':'North America',
    'MS Zaandam':'North America',
    'The Bahamas':'North America',
    'El Salvador':'North America',
    'Saint Lucia':'North America',
    'Dominican Republic':'North America',
    'Saint Kitts and Nevis':'North America',
    'Saint Vincent and the Grenadines':'North America',
#     '':'North America',
#     '':'North America',
#     '':'North America',
    'Fiji':'Australia',
    'Australia':'Australia',
    'New Zealand':'Australia',
    'Papua New Guinea':'Australia',
#     '':'Australia',
#     '':'Australia',
#     '':'Australia',
    'Togo':'Africa',
    'Chad':'Africa',
    'Mali':'Africa',
    'Libya':'Africa',
    'Ghana':'Africa',
    'Gabon':'Africa',
    'Egypt':'Africa',
    'Benin':'Africa',
    'Sudan':'Africa',
    'Niger':'Africa',
    'Kenya':'Africa',
    'Angola':'Africa',
    'Zambia':'Africa',
    'Rwanda':'Africa',
    'Guinea':'Africa',
    'Uganda':'Africa',
    'Malawi':'Africa',
    'Eritrea':'Africa',
    'Algeria':'Africa',
    'Liberia':'Africa',
    'Somalia':'Africa',
    'Senegal':'Africa',
    'Tunisia':'Africa',
    'Nigeria':'Africa',
    'Morocco':'Africa',
    'Namibia':'Africa',
    'Burundi':'Africa',
    'Eswatini':'Africa',
    'Zimbabwe':'Africa',
    'Tanzania':'Africa',
    'Cameroon':'Africa',
    'Ethiopia':'Africa',
    'Djibouti':'Africa',
    'Botswana':'Africa',
    'Mauritius':'Africa',
    'Cabo Verde':'Africa',
    'Cape Verde':'Africa',
    'Seychelles':'Africa',
    'The Gambia':'Africa',
    'Madagascar':'Africa',
    'Mauritania':'Africa',
    'Mozambique':'Africa',
    'South Sudan':'Africa',
    'South Sudan':'Africa',
    'Sierra Leone':'Africa',
    'Burkina Faso':'Africa',
    'South Africa':'Africa',
    'Guinea-Bissau':'Africa',
    'Cote d\'Ivoire':'Africa',
    'Western Sahara':'Africa',
    'Equatorial Guinea':'Africa',
    'Sao Tome and Principe':'Africa',
    'Republic of the Congo':'Africa',
    'Central African Republic':'Africa',
    'Democratic Republic of the Congo':'Africa',
    'Comoros':'Africa',
#     '':'Africa',
#     '':'Africa',
    'Peru':'South America',
    'Chile':'South America',
    'Guyana':'South America',
    'Brazil':'South America',
    'Ecuador':'South America',
    'Bolivia':'South America',
    'Uruguay':'South America',
    'Curacao':'South America',
    'Suriname':'South America',
    'Colombia':'South America',
    'Paraguay':'South America',
    'Argentina':'South America',
    'Venezuela':'South America',
    'Trinidad and Tobago':'South America'
#     '':'South America',
#     '':'South America',
#     '':'South America',
#     '':'South America',
#     '':'South America',
}

# %%
df.insert(loc=0, column='continentName', value=0)
df['continentName'] = df['countryName'].map(country_continent_dict)

# %%
df[df['continentName'].isnull()]

# %%
df.head(2)

# %%
df.to_csv(filename, index=False)
